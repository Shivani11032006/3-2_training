# %%
set1={23,1,"fruit",24.7}
print(set1)
# Out:
# {24.7, 1, 'fruit', 23}

# %%
list1=[23,1,"fruit",24.7]
print(list1)
# Out:
# [23, 1, 'fruit', 24.7]

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %%
mytuple = ("apple", "banana", "cherry")
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
birth_year = int(input("Enter your birth year: "))
current_year = 2025
age = current_year - birth_year
if age >= 0:
    print("Your age is:", age, "years")
else:
    print("Invalid year entered")
# Out:
# Enter your birth year:  2006
# Your age is: 19 years
